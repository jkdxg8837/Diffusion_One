# %% [markdown]
# # A simple 2D Flow Matching model

# %% [markdown]
# This notebook trains and evaluates a simple 2D FM model with CondOT (i.e., linear) scheduler.
#
# Dataset: 2D checkerboard
# Model (velocity): MLP

# %% [markdown]
# ## Imports and init device

# %%
import time
import torch

from torch import nn, Tensor

# flow_matching
from flow_matching.path.scheduler import CondOTScheduler
from flow_matching.path import AffineProbPath
from flow_matching.solver import Solver, ODESolver
from flow_matching.utils import ModelWrapper

# visualization
import matplotlib.pyplot as plt

from matplotlib import cm


# To avoide meshgrid warning
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module='torch')

# %%
if torch.cuda.is_available():
    device = 'cuda:0'
    print('Using gpu')
else:
    device = 'cpu'
    print('Using cpu.')
# Out:
# Using gpu

# %%
torch.manual_seed(42)

# %% [markdown]
# ## Dataset

# %%
def inf_train_gen(batch_size: int = 200, device: str = "cpu"):
    x1 = torch.rand(batch_size, device=device) * 4 - 2
    x2_ = torch.rand(batch_size, device=device) - torch.randint(high=2, size=(batch_size, ), device=device) * 2
    x2 = x2_ + (torch.floor(x1) % 2)

    data = 1.0 * torch.cat([x1[:, None], x2[:, None]], dim=1) / 0.45
    
    return data.float()

# %% [markdown]
# ## Model

# %%
# Activation class
class Swish(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x: Tensor) -> Tensor: 
        return torch.sigmoid(x) * x

# Model class
class MLP(nn.Module):
    def __init__(self, input_dim: int = 2, time_dim: int = 1, hidden_dim: int = 128):
        super().__init__()
        
        self.input_dim = input_dim
        self.time_dim = time_dim
        self.hidden_dim = hidden_dim

        self.main = nn.Sequential(
            nn.Linear(input_dim+time_dim, hidden_dim),
            Swish(),
            nn.Linear(hidden_dim, hidden_dim),
            Swish(),
            nn.Linear(hidden_dim, hidden_dim),
            Swish(),
            nn.Linear(hidden_dim, hidden_dim),
            Swish(),
            nn.Linear(hidden_dim, input_dim),
            )
    

    def forward(self, x: Tensor, t: Tensor) -> Tensor:
        sz = x.size()
        x = x.reshape(-1, self.input_dim)
        t = t.reshape(-1, self.time_dim).float()

        t = t.reshape(-1, 1).expand(x.shape[0], 1)
        h = torch.cat([x, t], dim=1)
        output = self.main(h)
        
        return output.reshape(*sz)

# %% [markdown]
# ## Train Velocity Flow Matching model

# %%
# training arguments
lr = 0.001
batch_size = 4096
iterations = 20001
print_every = 200 
hidden_dim = 512

# velocity field model init
vf = MLP(input_dim=2, time_dim=1, hidden_dim=hidden_dim).to(device) 

# instantiate an affine path object
path = AffineProbPath(scheduler=CondOTScheduler())

# init optimizer
optim = torch.optim.Adam(vf.parameters(), lr=lr) 


loss_history = []
# train
start_time = time.time()
for i in range(iterations):
    optim.zero_grad() 

    # sample data (user's responsibility): in this case, (X_0,X_1) ~ pi(X_0,X_1) = N(X_0|0,I)q(X_1)
    x_1 = inf_train_gen(batch_size=batch_size, device=device) # sample data
    x_0 = torch.randn_like(x_1).to(device)

    # sample time (user's responsibility)
    t = torch.rand(x_1.shape[0]).to(device) 

    # sample probability path
    path_sample = path.sample(t=t, x_0=x_0, x_1=x_1)

    # flow matching l2 loss
    loss = torch.pow( vf(path_sample.x_t,path_sample.t) - path_sample.dx_t, 2).mean() 
    loss_history.append(loss.item())
    # optimizer step
    loss.backward() # backward
    optim.step() # update
    
    # log loss
    if (i+1) % print_every == 0:
        elapsed = time.time() - start_time
        print('| iter {:6d} | {:5.2f} ms/step | loss {:8.3f} ' 
              .format(i+1, elapsed*1000/print_every, loss.item())) 
        start_time = time.time()
        # torch.save(vf.state_dict(), f"/home/u5649209/workspace/flow_matching/ckpts/raw_models/raw_model_{i}.pth")
        # torch.save(vf.state_dict(), f"raw_model_{i}.pth")
# Out:
# | iter    200 |  3.80 ms/step | loss    3.873
# | iter    400 |  2.51 ms/step | loss    3.813
# | iter    600 |  2.53 ms/step | loss    3.690
# | iter    800 |  2.51 ms/step | loss    3.881
# | iter   1000 |  2.53 ms/step | loss    3.727
# | iter   1200 |  2.52 ms/step | loss    3.827
# | iter   1400 |  2.53 ms/step | loss    3.744
# | iter   1600 |  2.52 ms/step | loss    3.760
# | iter   1800 |  2.53 ms/step | loss    3.856
# | iter   2000 |  2.52 ms/step | loss    3.772
# | iter   2200 |  2.53 ms/step | loss    3.763
# | iter   2400 |  2.52 ms/step | loss    3.707
# | iter   2600 |  2.53 ms/step | loss    3.773
# | iter   2800 |  2.52 ms/step | loss    3.677
# | iter   3000 |  2.53 ms/step | loss    3.760
# | iter   3200 |  2.52 ms/step | loss    3.804
# | iter   3400 |  2.53 ms/step | loss    3.861
# | iter   3600 |  2.52 ms/step | loss    3.790
# | iter   3800 |  2.52 ms/step | loss    3.815
# | iter   4000 |  2.51 ms/step | loss    3.684
# | iter   4200 |  2.52 ms/step | loss    3.820
# | iter   4400 |  2.51 ms/step | loss    3.760
# | iter   4600 |  2.52 ms/step | loss    3.744
# | iter   4800 |  2.52 ms/step | loss    3.691
# | iter   5000 |  2.52 ms/step | loss    3.983
# | iter   5200 |  2.52 ms/step | loss    3.706
# | iter   5400 |  2.52 ms/step | loss    3.638
# | iter   5600 |  2.52 ms/step | loss    3.855
# | iter   5800 |  2.66 ms/step | loss    3.721
# | iter   6000 |  2.67 ms/step | loss    3.780
# | iter   6200 |  3.76 ms/step | loss    3.711
# | iter   6400 |  2.81 ms/step | loss    3.755
# | iter   6600 |  2.51 ms/step | loss    3.842
# | iter   6800 |  2.53 ms/step | loss    3.824
# | iter   7000 |  2.52 ms/step | loss    3.764
# | iter   7200 |  2.52 ms/step | loss    3.874
# | iter   7400 |  2.52 ms/step | loss    3.692
# | iter   7600 |  2.52 ms/step | loss    3.822
# | iter   7800 |  2.77 ms/step | loss    3.839
# | iter   8000 |  2.52 ms/step | loss    3.729
# | iter   8200 |  2.54 ms/step | loss    3.851
# | iter   8400 |  2.52 ms/step | loss    3.770
# | iter   8600 |  2.54 ms/step | loss    3.739
# | iter   8800 |  2.52 ms/step | loss    3.750
# | iter   9000 |  2.53 ms/step | loss    3.838
# | iter   9200 |  2.64 ms/step | loss    3.757
# | iter   9400 |  2.54 ms/step | loss    3.892
# | iter   9600 |  2.53 ms/step | loss    3.644
# | iter   9800 |  2.52 ms/step | loss    3.847
# | iter  10000 |  2.53 ms/step | loss    3.705
# | iter  10200 |  2.53 ms/step | loss    3.892
# | iter  10400 |  2.53 ms/step | loss    3.597
# | iter  10600 |  2.53 ms/step | loss    3.833
# | iter  10800 |  2.53 ms/step | loss    3.689
# | iter  11000 |  2.53 ms/step | loss    3.658
# | iter  11200 |  2.53 ms/step | loss    3.644
# | iter  11400 |  2.53 ms/step | loss    3.764
# | iter  11600 |  2.53 ms/step | loss    3.713
# | iter  11800 |  2.53 ms/step | loss    3.788
# | iter  12000 |  4.62 ms/step | loss    3.661
# | iter  12200 |  3.03 ms/step | loss    3.764
# | iter  12400 |  2.54 ms/step | loss    3.746
# | iter  12600 |  2.53 ms/step | loss    3.774
# | iter  12800 |  2.53 ms/step | loss    3.869
# | iter  13000 |  2.53 ms/step | loss    3.702
# | iter  13200 |  2.53 ms/step | loss    3.679
# | iter  13400 |  2.54 ms/step | loss    3.784
# | iter  13600 |  2.53 ms/step | loss    3.853
# | iter  13800 |  2.54 ms/step | loss    3.740
# | iter  14000 |  2.53 ms/step | loss    3.625
# | iter  14200 |  2.54 ms/step | loss    3.796
# | iter  14400 |  2.53 ms/step | loss    3.693
# | iter  14600 |  2.53 ms/step | loss    3.723
# | iter  14800 |  2.54 ms/step | loss    3.879
# | iter  15000 |  5.49 ms/step | loss    3.654
# | iter  15200 |  6.20 ms/step | loss    3.694
# | iter  15400 |  6.15 ms/step | loss    3.770
# | iter  15600 |  6.13 ms/step | loss    3.677
# | iter  15800 |  6.09 ms/step | loss    3.688
# | iter  16000 |  6.22 ms/step | loss    3.837
# | iter  16200 |  6.10 ms/step | loss    3.834
# | iter  16400 |  6.10 ms/step | loss    3.873
# | iter  16600 |  3.84 ms/step | loss    3.751
# | iter  16800 |  2.51 ms/step | loss    3.725
# | iter  17000 |  2.53 ms/step | loss    3.739
# | iter  17200 |  2.51 ms/step | loss    3.908
# | iter  17400 |  2.54 ms/step | loss    3.743
# | iter  17600 |  2.51 ms/step | loss    3.727
# | iter  17800 |  2.53 ms/step | loss    3.697
# | iter  18000 |  2.52 ms/step | loss    3.796
# | iter  18200 |  4.26 ms/step | loss    3.714
# | iter  18400 |  6.18 ms/step | loss    3.722
# | iter  18600 |  6.20 ms/step | loss    3.829
# | iter  18800 |  6.08 ms/step | loss    3.656
# | iter  19000 |  6.18 ms/step | loss    3.743
# | iter  19200 |  6.09 ms/step | loss    3.759
# | iter  19400 |  6.19 ms/step | loss    3.687
# | iter  19600 |  6.19 ms/step | loss    3.767
# | iter  19800 |  5.95 ms/step | loss    3.677
# | iter  20000 |  6.12 ms/step | loss    3.872

# %% [markdown]
# Loss curve

# %%
plt.figure(figsize=(8, 4))
plt.plot(loss_history[:])
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Sample from trained model

# %%
class WrappedModel(ModelWrapper):
    def forward(self, x: torch.Tensor, t: torch.Tensor, **extras):
        return self.model(x, t)

wrapped_vf = WrappedModel(vf)

# %%
# step size for ode solver
step_size = 0.05

norm = cm.colors.Normalize(vmax=50, vmin=0)

batch_size = 50000  # batch size
eps_time = 1e-2
T = torch.linspace(0,1,10)  # sample times
T = T.to(device=device)

x_init = torch.randn((batch_size, 2), dtype=torch.float32, device=device)
solver = ODESolver(velocity_model=wrapped_vf)  # create an ODESolver class
sol = solver.sample(time_grid=T, x_init=x_init, method='midpoint', step_size=step_size, return_intermediates=True)  # sample from the model

# %% [markdown]
# ### Visualize the path

# %%
sol = sol.cpu().numpy()
T = T.cpu()

fig, axs = plt.subplots(1, 10,figsize=(20,20))

for i in range(10):
    H= axs[i].hist2d(sol[i,:,0], sol[i,:,1], 300, range=((-5,5), (-5,5)))
    
    cmin = 0.0
    cmax = torch.quantile(torch.from_numpy(H[0]), 0.99).item()
    
    norm = cm.colors.Normalize(vmax=cmax, vmin=cmin)
    
    _ = axs[i].hist2d(sol[i,:,0], sol[i,:,1], 300, range=((-5,5), (-5,5)), norm=norm)
    
    axs[i].set_aspect('equal')
    axs[i].axis('off')
    axs[i].set_title('t= %.2f' % (T[i]))
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Compute and Visualize Model Log-likelihood

# %%
from torch.distributions import Independent, Normal

# %%
# sample with likelihood

T = torch.tensor([1., 0.])  # sample times
T = T.to(device=device)

grid_size = 200
x_1 = torch.meshgrid(torch.linspace(-5, 5, grid_size), torch.linspace(-5, 5, grid_size))
x_1 = torch.stack([x_1[0].flatten(), x_1[1].flatten()], dim=1).to(device)

print(x_1)
# Out:
# tensor([[-5.0000, -5.0000],
#         [-5.0000, -4.9497],
#         [-5.0000, -4.8995],
#         ...,
#         [ 5.0000,  4.8995],
#         [ 5.0000,  4.9497],
#         [ 5.0000,  5.0000]], device='cuda:0')

# %%
# source distribution is an isotropic gaussian
gaussian_log_density = Independent(Normal(torch.zeros(2, device=device), torch.ones(2, device=device)), 1).log_prob

# compute log likelihood with unbiased hutchinson estimator, average over num_acc
num_acc = 10
log_p_acc = 0

for i in range(num_acc):
    _, log_p = solver.compute_likelihood(x_1=x_1, method='midpoint', step_size=step_size, exact_divergence=False, log_p0=gaussian_log_density)
    log_p_acc += log_p

log_p_acc /= num_acc

# compute with exact divergence
_, exact_log_p = solver.compute_likelihood(x_1=x_1, method='midpoint', step_size=step_size, exact_divergence=True, log_p0=gaussian_log_density)

# %%
likelihood = torch.exp(log_p_acc).cpu().reshape(grid_size, grid_size).t().detach().numpy()
exact_likelihood = torch.exp(exact_log_p).cpu().reshape(grid_size, grid_size).t().detach().numpy()

fig, axs = plt.subplots(1, 2,figsize=(10,10))

cmin = 0.0
cmax = 1/32 # 1/32 is the gt likelihood value

norm = cm.colors.Normalize(vmax=cmax, vmin=cmin)

axs[0].imshow(likelihood, extent=(-5, 5, -5, 5), origin='lower', cmap='viridis', norm=norm)
axs[0].set_title('Model Likelihood, Hutchinson Estimator, #acc=%d' % num_acc)

axs[1].imshow(exact_likelihood, extent=(-5, 5, -5, 5), origin='lower', cmap='viridis', norm=norm)
axs[1].set_title('Exact Model Likelihood')

fig.colorbar(cm.ScalarMappable(norm=norm, cmap='viridis'), ax=axs, orientation='horizontal', label='density')
plt.show()
